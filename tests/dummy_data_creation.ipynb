# %%
import pandas as pd
import numpy as np
import random

# Column names
columns = [
    "Incdence_Date","Refresh_Date","Partner_Organization","Channel","Asset_Name",
    "Seasonal_Event_Name","Social_Platform","Social_Account","Account_Handle",
    "Unique_Social_ID","Digital_Source","Unique_Digital_ID","Media_Type","URL","Market",
    "Unique_Broadcast_ID","Broadcast_Network_(US)","Broadcast_Network_(Local_H)",
    "Broadcast_Network_(Local _A)","Broadcast_Network_(UK)","Broadcast_Network_(SP)",
    "Total_Impressions","Social_Impressions","Digital_Impressions",
    "Broadcast_Impressions (US|HHLD)","Broadcast_Impressions_(US National|P2+)",
    "Broadcast_Impressions_(US Local H|P2+)","Broadcast_Impressions_(US Local A|P2+)",
    "Broadcast_Impressions_(UK|P2+)","Broadcast_Impressions_(SP|P2+)",
    "Engagements","Video_Views","Exposures","Video_Length","Duration_per_Exposure",
    "30_Sec_Equivalent","Duration_Factor","EXT_Factor","ME_Score","ME_Value",
    "Home_Team","Away_Team","Brand_1","Brand_2","Content_Message","Customer_Journey_Stage",
    "CSA_Targeted","Audience_Persona"
]

# Generate random data
data = []
for _ in range(10):
    row = [
        pd.Timestamp("2025-10-22") + pd.to_timedelta(random.randint(0,30), unit="d"),  # Incdence_Date
        pd.Timestamp("2025-10-22") + pd.to_timedelta(random.randint(0,30), unit="d"),  # Refresh_Date
        f"Partner_{random.randint(1,5)}",  # Partner_Organization
        random.choice(["Online","TV","Social"]),  # Channel
        f"Asset_{random.randint(1,10)}",  # Asset_Name
        f"Event_{random.randint(1,3)}",  # Seasonal_Event_Name
        random.choice(["Facebook","Twitter","Instagram"]),  # Social_Platform
        f"Account_{random.randint(1,10)}",  # Social_Account
        f"Handle_{random.randint(1,10)}",  # Account_Handle
        f"UID_{random.randint(1000,9999)}",  # Unique_Social_ID
        random.choice(["Source_A","Source_B"]),  # Digital_Source
        f"DID_{random.randint(1000,9999)}",  # Unique_Digital_ID
        random.choice(["Video","Image"]),  # Media_Type
        f"https://example.com/{random.randint(1,10)}",  # URL
        random.choice(["US","UK","SP"]),  # Market
        f"UBID_{random.randint(1000,9999)}",  # Unique_Broadcast_ID
        f"Network_{random.randint(1,5)}",  # Broadcast_Network_(US)
        f"Network_{random.randint(1,5)}",  # Broadcast_Network_(Local_H)
        f"Network_{random.randint(1,5)}",  # Broadcast_Network_(Local _A)
        f"Network_{random.randint(1,5)}",  # Broadcast_Network_(UK)
        f"Network_{random.randint(1,5)}",  # Broadcast_Network_(SP)
        random.randint(1000,10000),  # Total_Impressions
        random.randint(100,5000),  # Social_Impressions
        random.randint(100,5000),  # Digital_Impressions
        random.randint(100,5000),  # Broadcast_Impressions (US|HHLD)
        random.randint(100,5000),  # Broadcast_Impressions_(US National|P2+)
        random.randint(100,5000),  # Broadcast_Impressions_(US Local H|P2+)
        random.randint(100,5000),  # Broadcast_Impressions_(US Local A|P2+)
        random.randint(100,5000),  # Broadcast_Impressions_(UK|P2+)
        random.randint(100,5000),  # Broadcast_Impressions_(SP|P2+)
        random.randint(10,1000),  # Engagements
        random.randint(10,1000),  # Video_Views
        random.randint(10,1000),  # Exposures
        random.randint(30,300),   # Video_Length
        round(random.uniform(0.1,5.0),2),  # Duration_per_Exposure
        random.randint(0,10),     # 30_Sec_Equivalent
        round(random.uniform(0.5,2.0),2),  # Duration_Factor
        round(random.uniform(0.5,2.0),2),  # EXT_Factor
        round(random.uniform(0,100),2),    # ME_Score
        round(random.uniform(0,5000),2),   # ME_Value
        f"Team_{random.randint(1,5)}",  # Home_Team
        f"Team_{random.randint(1,5)}",  # Away_Team
        f"Brand_{random.randint(1,5)}",  # Brand_1
        f"Brand_{random.randint(1,5)}",  # Brand_2
        f"Message_{random.randint(1,5)}",  # Content_Message
        random.choice(["Awareness","Consideration","Decision"]),  # Customer_Journey_Stage
        random.choice([True, False]),  # CSA_Targeted
        f"Persona_{random.randint(1,5)}"  # Audience_Persona
    ]
    data.append(row)

# Save to CSV
df = pd.DataFrame(data, columns=columns)
df.to_csv(r"C:\Users\v-sromanoodd\Documents\ai_agent_msft\azure-agent-mkt\data\earned_dummy_data.csv", index=False)
print("earned_dummy_data.csv created with 10 random rows.")
# Out:
# earned_dummy_data.csv created with 10 random rows.
