# %%
import pandas as pd

# %%
contractual = pd.read_csv(r'C:\Users\v-sromanoodd\Documents\ai_agent_msft\azure-agent-mkt\data\contractual_dummy_data.csv')
contractual
# Out:
#   Incidence_Date Refresh_Date Incidence_Timezone Partner_Organization Channel  \
# 0     2025-07-29   2024-12-18                UTC            Microsoft      TV
# 1     2025-05-15   2025-04-04                UTC               Google  Online
# 2     2024-12-31   2024-11-17                UTC            Microsoft   Event
# 3     2025-02-21   2025-05-07                PST               Google  Online
# 4     2025-01-27   2025-06-06                CET               Google   Event
# 5     2024-10-31   2025-09-23                PST                Adobe      TV
# 6     2025-10-15   2025-01-05                PST               Amazon  Online
# 7     2025-01-21   2025-04-08                PST                Adobe      TV
# 8     2025-03-04   2025-03-07                UTC               Google  Online
# 9     2024-11-22   2025-06-05                EST               Amazon  Social
#
#   Asset_Type Seasonal_Event_Name Social_Platform Social_Account  \
# ...

# %%
contractual.groupby('Partner_Organization')['Engagements'].sum().reset_index()
# Out:
#   Partner_Organization  Engagements
# 0                Adobe        12241
# 1               Amazon        26149
# 2               Google        28563
# 3            Microsoft        12915

# %%
contractual['ME_Value'].sum()
# Out:
# np.float64(57851.21000000001)

# %%
earned = pd.read_csv(r'C:\Users\v-sromanoodd\Documents\ai_agent_msft\azure-agent-mkt\data\earned_dummy_data.csv')
earned
# Out:
#   Incdence_Date Refresh_Date Partner_Organization Channel Asset_Name  \
# 0    2025-11-16   2025-10-29            Partner_4  Online    Asset_3
# 1    2025-11-19   2025-11-04            Partner_1  Social    Asset_1
# 2    2025-11-21   2025-10-26            Partner_3  Online    Asset_8
# 3    2025-10-22   2025-11-02            Partner_5      TV    Asset_2
# 4    2025-11-05   2025-11-20            Partner_1  Online    Asset_3
# 5    2025-10-25   2025-11-11            Partner_3  Social    Asset_4
# 6    2025-11-12   2025-11-06            Partner_3  Social   Asset_10
# 7    2025-11-10   2025-11-20            Partner_2  Social    Asset_6
# 8    2025-11-07   2025-10-27            Partner_5  Social    Asset_8
# 9    2025-11-14   2025-11-13            Partner_1  Social    Asset_1
#
#   Seasonal_Event_Name Social_Platform Social_Account Account_Handle  \
# 0             Event_3       Instagram      Account_7       Handle_6
# 1             Event_3         Twitter      Account_4       Handle_6
# ...

# %%
earned.groupby('Partner_Organization')['Engagements'].sum().reset_index()
# Out:
#   Partner_Organization  Engagements
# 0            Partner_1          536
# 1            Partner_2          265
# 2            Partner_3         1167
# 3            Partner_4          611
# 4            Partner_5         1296

# %%
earned['ME_Value'].sum()
# Out:
# np.float64(22238.839999999997)
